# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import astropy

# %%
with open("hoverr.txt", "r") as f:
    file_content = f.read()

# %%
text_file = open("hoverr.txt", "r")
lines = text_file.readlines()
print lines
# Out:
# ['0.4076886048803847, -0.6314089747932545\r\n', '0.5422366433794408, -0.6678331503804653\r\n', '0.6498180234468323, -0.722398100346464\r\n', '0.7484139132472309, -0.7814965459687118\r\n', '0.8738949604337893, -0.8587765164925003\r\n', '1.0262000392223785, -0.9814797363780763\r\n', '1.169550190636039, -1.0950955896897778\r\n', '1.2949802996691568, -1.1950769972637716\r\n', '1.3845499486798105, -1.276870088182433\r\n', '1.4831254632188329, -1.3450491086247631\r\n', '1.5548056327410076, -1.399586891575593\r\n', '1.6534422730641594, -1.4405241875576764\r\n', '1.734219996790896, -1.4405853133418056\r\n', '1.8240035860460027, -1.4270323686496038\r\n', '1.9048322479261803, -1.4043920573835273\r\n', '1.9766142937552367, -1.413526966233947\r\n', '2.0573207040671577, -1.4453701038883637\r\n', '2.146910728339187, -1.5180826199869424\r\n', '2.209595219963681, -1.581694186004063\r\n', '2.29013862818459, -1.6861819222191372\r\n', '2.3975468185302815, -1.817931758155835\r\n', '2.487055341756806, -1
# ...

# %%
#These are the data for R, the distance from SMBH to the star
with open('hoverr.txt') as inf:
    for line in inf:
        parts = line.split() # split line into parts
        if len(parts) > 1:   # if at least 2 parts/columns
            print parts[0]   # print column 1
# Out:
# 0.4076886048803847,
# 0.5422366433794408,
# 0.6498180234468323,
# 0.7484139132472309,
# 0.8738949604337893,
# 1.0262000392223785,
# 1.169550190636039,
# 1.2949802996691568,
# 1.3845499486798105,
# 1.4831254632188329,
# 1.5548056327410076,
# 1.6534422730641594,
# 1.734219996790896,
# 1.8240035860460027,
# 1.9048322479261803,
# 1.9766142937552367,
# 2.0573207040671577,
# 2.146910728339187,
# 2.209595219963681,
# 2.29013862818459,
# 2.3975468185302815,
# 2.487055341756806,
# 2.5676802510232197,
# 2.6304156808011556,
# 2.729042133493619,
# 2.809763825251571,
# 2.8994811949072044,
# 2.9623185009920214,
# 3.061153800113592,
# 3.18694557003614,
# 3.5194087099148565,
# 4.022596164866428,
# 4.552729902988286,
# 5.002004416337904,
# 5.388375404003229,
# 6.062261704950934,
# 6.601391120970474,
# 6.9203811192640465,

# %%
#These are the data for h/R 
with open('hoverr.txt') as inf:
    for line in inf:
        parts = line.split() # split line into parts
        if len(parts) > 1:   # if at least 2 parts/columns
            print parts[1]   # print column 2
# Out:
# -0.6314089747932545
# -0.6678331503804653
# -0.722398100346464
# -0.7814965459687118
# -0.8587765164925003
# -0.9814797363780763
# -1.0950955896897778
# -1.1950769972637716
# -1.276870088182433
# -1.3450491086247631
# -1.399586891575593
# -1.4405241875576764
# -1.4405853133418056
# -1.4270323686496038
# -1.4043920573835273
# -1.413526966233947
# -1.4453701038883637
# -1.5180826199869424
# -1.581694186004063
# -1.6861819222191372
# -1.817931758155835
# -1.9269665735347423
# -1.995132010469488
# -2.036042139436403
# -2.081519722828528
# -2.1065524293678823
# -2.122511352840948
# -2.1180186077074517
# -2.0704202991937333
# -2.0092215037112684
# -1.8414821644300567
# -1.5876064076801146
# -1.3246704513714669
# -1.0979956685590186
# -0.9053254990453337
# -0.5766640433517641
# -0.304654303976826
# -0.14144506447496724

# %%
x = [row.split(' ')[1] for row in 'hoverr.txt']
y = [row.split(' ')[0] for row in 'hoverr.txt']

fig = plt.figure()

ax1 = fig.add_subplot(111)

ax1.set_title("h/a vs. a")    
ax1.set_xlabel('a')
ax1.set_ylabel('a')

ax1.plot(x,y, c='r', label='hoverr.txt')

leg = ax1.legend()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-41-11ddba41f541> in <module>()
#       1
#       2
# ----> 3 x = [row.split(' ')[1] for row in 'hoverr.txt']
#       4 y = [row.split(' ')[0] for row in 'hoverr.txt']
#       5
#
# IndexError: list index out of range
